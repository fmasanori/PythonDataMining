# %%
import numpy as np
import pandas as pd
import json
import requests

# %%
print('hello world')
# Out:
# hello world

# %%
print('teste 2')
# Out:
# teste 2

# %%
req = requests.get('https://services6.arcgis.com/8mobQf5ZkZ3Ps1Rs/arcgis/rest/services/Respiradores_em_2019_WFL1/FeatureServer/7/query?where=1%3D1&outFields=P_Respiradores_SUS&returnGeometry=false&outSR=4326&f=json',stream=True, timeout=None)

if req.status_code == 200:
    reddit_data = json.loads(req.content)

# %%
print(req.content)
# Out:
# b'{"objectIdFieldName":"OBJECTID","uniqueIdField":{"name":"OBJECTID","isSystemMaintained":true},"globalIdFieldName":"","geometryType":"esriGeometryPolygon","spatialReference":{"wkid":4326,"latestWkid":4326},"fields":[{"name":"P_Respiradores_SUS","type":"esriFieldTypeDouble","alias":"Percentual de respiradores do SUS","sqlType":"sqlTypeOther","domain":null,"defaultValue":null}],"exceededTransferLimit":true,"features":[{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":100}},{"attributes":{"P_Respiradores_SUS":90}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":100}},{"attributes":{"P_Respiradores_SUS":100}},{"attributes":{"P_Respiradores_SUS":0}},{"attributes":{"P_Respiradores_SUS":52.38095238095
# ...
